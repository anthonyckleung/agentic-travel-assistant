# %% [markdown]
# # Eval Dataset

# %%
from openai import OpenAI
import os
import psycopg2
import instructor
from pydantic import BaseModel
import openai

# %%
postgres_username = os.getenv("POSTGRES_USERNAME")
postgres_pwd = os.getenv("POSTGRES_PASSWORD")

# %%
conn = psycopg2.connect(
    dbname="postgresdb",
    user=postgres_username,
    password=postgres_pwd,
    host="host.docker.internal",  # e.g., "localhost"
    port="5433"        # default PostgreSQL port
)
cursor = conn.cursor()

# %%
cursor.execute("SELECT * FROM public.us_attractions")
rows = cursor.fetchall()

# for row in rows:
#     print(row)
row_list = [", ".join(map(str, row)) for row in rows]
formatted_rows = "\n".join(row_list)
row_list[:2]
# Out:
# ['Forsyth Park, Park, 4.8, 16538.0, Park, Tourist attraction, Forsyth Park, Savannah, GA 31401, Savannah, USA, GA, None, Nature, 79382.4, 4.67, Atlanta, Augusta, Chattanooga, Savannah',
#  'The Cathedral Basilica of St. John the Baptist, Catholic cathedral, 4.8, 5911.0, Catholic cathedral, Catholic church, Tourist attraction, The Cathedral Basilica of St. John the Baptist, 222 E Harris St, Savannah, GA 31401, Savannah, USA, GA, None, Religious, 28372.8, 4.8, Atlanta, Augusta, Chattanooga, Savannah']

# %% [markdown]
# ## Render prompt to generate synthetic Eval reference dataset

# %%
import json

output_schema = {
    "type": "array",
    "items": {
        "type": "object",
        "properties": {
            "question": {
                "type": "string",
                "description": "Suggested question.",
            },
            "chunk_ids": {
                "type": "array",
                "items": {
                    "type": "integer",
                    "description": "Index of the chunk that could be used to answer the question.",
                },
            },
            "answer_example": {
                "type": "string",
                "description": "Suggested answer grounded in the contexr.",
            },
            "reasoning": {
                "type": "string",
                "description": "Reasoning why the question could be answered with the chunks.",
            },
        },
    },
}


SYSTEM_PROMPT = f"""
I am building a RAG application. I have a collection of 50 chunks of text.
The RAG application will act as a travel booking assistant that can answer questions about US tourist attraction places we have available.
I will provide all of the available locations to you with indexes of each chunk.
Each chunk represents a record from SQL table with the following schema:
Columns:
- name VARCHAR(250)
- main_category VARCHAR(250)
- rating REAL
- reviews REAL
- categories VARCHAR(250)
- address VARCHAR(250)
- city VARCHAR(250)
- country VARCHAR(250)
- state VARCHAR(250)
- zipcode INTEGER
- broader_category VARCHAR(250)
- weighted_score REAL
- weighted_average REAL
- all_cities VARCHAR(250)
I want you to come up with 30 questions to which the answers could be grounded in the chunk context.
As an output I need you to provide me the list of questions and the indexes of the chunks that could be used to answer them.
Also, provide an example answer to the question given the context of the chunks.
Also, provide the reason why you chose the chunks to answer the questions.
Try to have a mix of questions that could use multipple chunks and questions that could use single chunk.
Also, include 5 questions that can't be answered with the available chunks.


{json.dumps(output_schema, indent=2)}


I need to be able to parse the json output.
"""

USER_PROMPT = f"""
Here is the list of chunks, each list element is a dictionary with id and text:
{[{"id": i, "text": data} for i, data in enumerate(row_list)]}
"""

# %%
print(USER_PROMPT)
# Out:
# Here is the list of chunks, each list element is a dictionary with id and text:
# [{'id': 0, 'text': 'Forsyth Park, Park, 4.8, 16538.0, Park, Tourist attraction, Forsyth Park, Savannah, GA 31401, Savannah, USA, GA, None, Nature, 79382.4, 4.67, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 1, 'text': 'The Cathedral Basilica of St. John the Baptist, Catholic cathedral, 4.8, 5911.0, Catholic cathedral, Catholic church, Tourist attraction, The Cathedral Basilica of St. John the Baptist, 222 E Harris St, Savannah, GA 31401, Savannah, USA, GA, None, Religious, 28372.8, 4.8, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 2, 'text': 'Fort Pulaski National Monument, Monument, 4.8, 5221.0, Monument, Historical place, Historical landmark, Tourist attraction, Fort Pulaski National Monument, 101 Fort Pulaski Rd, Savannah, GA, Savannah, USA, GA, None, Cultural, 25060.8, 4.53, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 3, 'text': 'Fountain at Forsyth Park, Historical landmark, 4.8, 4234.0, Historical landmark, Tourist attraction, Fountain at Forsyth Park, 1 W Gaston St, Savannah, GA 31401, Savannah, USA, GA, None, Cultural, 20323.2, 4.53, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 4, 'text': 'Wormsloe State Historic Site, Historical place museum, 4.5, 3615.0, Historical place museum, Museum, Park, State park, Wormsloe State Historic Site, 7601 Skidaway Rd, Savannah, GA 31406, Savannah, USA, GA, None, Cultural, 16267.5, 4.53, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 5, 'text': 'American Prohibition Museum, Museum, 4.6, 3113.0, Museum, Art museum, Heritage museum, Historical place museum, History museum, Tourist attraction, American Prohibition Museum, 209 W Saint Julian Street, Savannah, GA 31401, Savannah, USA, GA, None, Cultural, 14319.8, 4.53, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 6, 'text': 'Sorrel Weed House Museum, History museum, 4.6, 2392.0, History museum, Ghost town, Haunted house, Historical landmark, Historical place museum, Tour operator, Tourist attraction, Sorrel Weed House Museum, 6 W Harris St, Savannah, GA 31401, Savannah, USA, GA, None, Cultural, 11003.2, 4.53, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 7, 'text': 'Owens-Thomas House & Slave Quarters, Historical place museum, 4.5, 2145.0, Historical place museum, Historical landmark, History museum, Museum, Tourist attraction, Owens-Thomas House & Slave Quarters, 124 Abercorn St, Savannah, GA 31401, Savannah, USA, GA, None, Cultural, 9652.5, 4.53, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 8, 'text': 'Old Fort Jackson, Historical landmark, 4.7, 2081.0, Historical landmark, Museum, Tourist attraction, Old Fort Jackson, 1 Fort Jackson Rd, Savannah, GA 31404, Savannah, USA, GA, None, Cultural, 9780.7, 4.53, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 9, 'text': 'Hearse Ghost Tours, Tourist attraction, 4.9, 1912.0, Tourist attraction, Entertainment agency, Tour operator, Travel clinic, Hearse Ghost Tours, 1410 E Broad St, Savannah, GA 31401, Savannah, USA, GA, None, Entertainment, 9368.8, 4.59, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 10, 'text': 'Andrew Low House, Museum, 4.6, 1736.0, Museum, Historical place museum, Tourist attraction, Andrew Low House, 329 Abercorn St, Savannah, GA 31401, Savannah, USA, GA, None, Cultural, 7985.6, 4.53, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 11, 'text': 'Oatland Island Wildlife Center, Wildlife park, 4.7, 1671.0, Wildlife park, Wildlife refuge, Oatland Island Wildlife Center, 711 Sandtown Rd, Savannah, GA 31410, Savannah, USA, GA, None, Entertainment, 7853.7, 4.59, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 12, 'text': 'Daffin Park, Park, 4.5, 1470.0, Park, Tourist attraction, Daffin Dog Park, E Victory Dr, Savannah, GA 31404, Savannah, USA, GA, None, Nature, 6615.0, 4.67, Atlanta, Augusta, Chattanooga, Savannah'}, {'id': 13, 'text': "Jepson Center & Telfair Children's Art Museum (CAM), Art museum, 4.5, 1251.0, Art museum, Modern art museum, Tourist attraction, Jepson Center & Telfair Children's Art Museum (CAM), 207 W York St, Savann ...

# %% [markdown]
# ## Generate synthetic eval reference data

# %%
response = openai.chat.completions.create(
    model="gpt-4.1",
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": USER_PROMPT}
    ]
)

print(response.choices[0].message.content)
# Out:
# ```json
# [
#   {
#     "question": "What are some top-rated tourist attractions in Savannah, Georgia?",
#     "chunk_ids": [0, 1, 2, 3, 4, 5, 9],
#     "answer_example": "Some top-rated tourist attractions in Savannah, Georgia include Forsyth Park (4.8 rating), The Cathedral Basilica of St. John the Baptist (4.8), Fort Pulaski National Monument (4.8), and Hearse Ghost Tours (4.9).",
#     "reasoning": "Chunks 0–5 and 9 represent highly-rated tourist attractions in Savannah, GA, based on their ratings and city information."
#   },
#   {
#     "question": "Are there any Catholic cathedrals listed as attractions?",
#     "chunk_ids": [1, 90, 272, 763, 1178, 1479, 1517, 1620, 1783, 1862, 1950, 2177, 2722, 2917],
#     "answer_example": "Some Catholic cathedrals featured include The Cathedral Basilica of St. John the Baptist in Savannah, Cathedral of St. John the Evangelist in Lafayette, and the Cathedral Basilica of the Immaculate Conception in Denver.",
#     "reasoning": "Chunks contain 'Catholic cathedral' in the category or name, filtered across cities."
#   },
#   {
#     "question": "Which museums in Orlando, FL, focus on art?",
#     "chunk_ids": [156, 151, 146],
#     "answer_example": "In Orlando, you can visit the Mennello Museum of American Art, Orlando Museum of Art, and the Museum of Illusions Orlando.",
#     "reasoning": "These are the relevant art museums in Orlando based on their city and category."
#   },
#   {
#     "question": "List parks in Atlanta, GA, that are highly rated.",
#     "chunk_ids": [1855, 1856, 1863, 1871, 1884, 1890],
#     "answer_example": "Highly rated parks in Atlanta include Piedmont Park (4.8), Centennial Olympic Park (4.6), and Freedom Park (4.7).",
#     "reasoning": "Chunks are parks in Atlanta with high ratings and matching city/state."
#   },
#   {
#     "question": "Are there any themed sightseeing tours or 'Ghost Tours' in Savannah?",
#     "chunk_ids": [6, 9],
#     "answer_example": "Yes, Sorrel Weed House Museum offers ghost tours, and Hearse Ghost Tours is a highly rated tour operator in Savannah.",
#     "reasoning": "Chunks 6 and 9 mention ghost tours and tour operators related to the theme."
#   },
#   {
#     "question": "What museums in Dallas are suitable for children?",
#     "chunk_ids": [62, 66, 75, 76],
#     "answer_example": "In Dallas, the Museum of Illusions Dallas, Dallas Holocaust and Human Rights Museum, and Crow Museum of Asian Art of The University of Texas at Dallas provide engaging experiences for children.",
#     "reasoning": "Chunks are Dallas museums that, by name or type, offer child-friendly or educational experiences."
#   },
#   {
#     "question": "Which zoos are available in West Palm Beach, FL?",
#     "chunk_ids": [481],
#     "answer_example": "The Palm Beach Zoo in West Palm Beach is a top-rated option to visit.",
#     "reasoning": "Chunk 481 lists 'Palm Beach Zoo' and matches the city/state."
#   },
#   {
#     "question": "What attractions are available for nature lovers in Salt Lake City?",
#     "chunk_ids": [264, 265, 271, 273, 280],
#     "answer_example": "Nature lovers visiting Salt Lake City can explore Liberty Park, Sugar House Park, Jordan Park, International Peace Gardens, and The Living Room Trailhead.",
#     "reasoning": "Chunks list nature parks, preserves, and hiking areas, all with Salt Lake City as the city."
#   },
#   {
#     "question": "Can you name some public beaches in Naples, FL, suitable for a family day?",
#     "chunk_ids": [941, 942],
#     "answer_example": "Family-friendly public beaches in Naples include Lowdermilk Park and Clam Pass Park.",
#     "reasoning": "Both chunks are categorized as public beaches and are in Naples, FL."
#   },
#   {
#     "question": "Where can I see historical landmarks in Boston?",
#     "chunk_ids": [177, 179, 181, 189, 184, 192, 184, 193, 204],
#     "answer_example": "Historical landmarks in Boston include the Bunker Hill Monument, The Paul Revere House, Old State House, and Paul Revere Statue.",
#     "reasoning": "Chunks are Boston historical landmarks based on category and city."
#   },
#   {
#     "question": "What are the main tourist attractions in San Francisco involving parks or nature?",
#     "chunk_ids": [884, 894, 886, 889, 896, 900, 903, 910],
#     "answer_example": "San Francisco offers many nature attractions, such as Golden Gate Park, Presidio of San Francisco, Dolores Park, Twin Peaks, Crissy Field, Salesforce Park, 16th Avenue Tiled Steps, and Point Bonita Lighthouse.",
#     "reasoning": "Chunks match parks, nature, and scenic categories in San Francisco."
#   },
#   {
#     "question": "Are there any art museums in Minneapolis, MN?",
#     "chunk_ids": [1435, 1448, 1451, 1443, 1426],
#     "answer_example": "The Minneapolis Institute of Art, The Museum of Russian Art, Weisman Art Museum, Memorial Art Gallery, and Burchfield Penney Art Center are notable art museums in Minneapolis.",
#     "reasoning": "These chunks pertain to art museums in Minneapolis."
#   },
#   {
#     "question": "Which parks in Portland, OR are best for garden lovers?",
#     "chunk_ids": [2841, 2842, 2848, 2853],
#     "answer_example": "Garden lovers in Portland can visit the International Rose Test Garden, Portland Japanese Garden, Crystal Springs Rhododendron Garden, and World Forestry Center.",
#     "reasoning": "These parks/gardens are in Portland and have a garden focus."
#   },
#   {
#     "question": "Do any attractions in Philadelphia offer observation decks or skyline views?",
#     "chunk_ids": [191, 329],
#     "answer_example": "Observation decks in Philadelphia include View Boston (800 Boylston St, but this may be a data error; more accurately, Sky View Observatory - Columbia Center and Sky View Observatory in Seattle have observation decks).",
#     "reasoning": "Chunk 191 in the Philadelphia set may be a data input error, but generally, observatories or skyline views are filtered for with city match."
#   },
#   {
#     "question": "Which Dallas attractions are best for history buffs?",
#     "chunk_ids": [56, 58, 76],
#     "answer_example": "History buffs in Dallas can visit The Sixth Floor Museum at Dealey Plaza, the John F. Kennedy Memorial Plaza, and Old Red Museum of Dallas County History & Culture.",
#     "reasoning": "Chunks are Dallas museums or landmarks with a history focus."
#   },
#   {
#     "question": "Are there any theme parks or amusement parks in Orlando, FL?",
#     "chunk_ids": [122, 123, 124, 126, 127, 128, 129, 130, 131, 132, 133, 136, 137, 138, 140, 155],
#     "answer_example": "Orlando offers many theme and amusement parks, including Magic Kingdom, Universal Orlando Resort, Epcot, Universal Studios Florida, Disney's Animal Kingdom, SeaWorld, Islands of Adventure, ICON Park, Aquatica Orlando, Volcano Bay, Gatorland, Fun Spot America, Disney's Typhoon Lagoon, and Discovery Cove.",
#     "reasoning": "These chunks are all major theme/amusement parks in Orlando."
#   },
#   {
#     "question": "What are notable tourist attractions in Charleston, SC?",
#     "chunk_ids": [1734, 1735, 1736, 1737, 1740],
#     "answer_example": "Notable attractions in Charleston include Angel Oak Tree, Magnolia Plantation and Gardens, South Carolina Aquarium, Rainbow Row, and Middleton Place.",
#     "reasoning": "Chunks are Charleston's top-rated and popular attractions."
#   },
#   {
#     "question": "Where might I find hiking trails in Sedona, AZ?",
#     "chunk_ids": [2243, 2244, 2246, 2247, 2248, 2249, 2250, 2252, 2257, 2262],
#     "answer_example": "Sedona is famous for hiking, with trails like Devil's Bridge Trailhead, Bell Rock Trailhead, Bell Rock, West Fork Oak Creek Trailhead, Soldier Pass Trailhead, Boynton Canyon Trail, Fay Canyon Trailhead, Mescal Trailhead, Red Rock-Secret Mountain Wilderness, and Submarine Rock.",
#     "reasoning": "Chunks are Sedona hiking trailheads and related natural attractions."
#   },
#   {
#     "question": "Which zoos are present in the Midwest region (Chicago, St. Louis, Cleveland)?",
#     "chunk_ids": [1013, 1561, 1580, 1905, 2326],
#     "answer_example": "Zoos in the Midwest include Lincoln Park Zoo (Chicago), Saint Louis Zoo (St. Louis), Milwaukee County Zoo, Cleveland Metroparks Zoo, and Omaha's Henry Doorly Zoo.",
#     "reasoning": "Chunks filtered for zoos in the specified Midwest cities."
#   },
#   {
#     "question": "Are there any attractions in Boston related to American history?",
#     "chunk_ids": [176, 181, 184, 190, 193],
#     "answer_example": "American history attractions in Boston include the Boston Tea Party Ships & Museum, Old State House, Boston Massacre Site, Old South Meeting House, and Freedom Trail Foundation.",
#     "reasoning": "Chunks filtered for history museums, historical sites in Boston."
#   },
#   {
#     "question": "Are there famous aquariums among the available attractions?",
#     "chunk_ids": [801, 172, 232, 1053, 973],
#     "answer_example": "Famous aquariums include Mote Marine Laboratory & Aquarium (Sarasota), New England Aquarium (Boston), National Aquarium (Baltimore), Shedd Aquarium (Chicago), and Tennessee Aquarium (Chattanooga).",
#     "reasoning": "Chunks have high review counts and are aquariums."
#   },
#   {
#     "question": "Is there a zoo in Des Moines, IA?",
#     "chunk_ids": [100],
#     "answer_example": "Blank Park Zoo is located in Des Moines and is a popular attraction.",
#     "reasoning": "Chunk 100 is a zoo in Des Moines."
#   },
#   {
#     "question": "Where can tourists experience art and science together in a single location in Boston?",
#     "chunk_ids": [173, 174, 175],
#     "answer_example": "In Boston, the Museum of Science, Museum of Fine Arts, and Isabella Stewart Gardner Museum offer both artistic and scientific experiences.",
#     "reasoning": "Chunks are museums in Boston with art and/or science as a focus."
#   },
#   {
#     "question": "Which Nashville attractions are related to music and musicians?",
#     "chunk_ids": [1542, 1544, 1554, 1558, 1567],
#     "answer_example": "Nashville's music attractions include the Country Music Hall of Fame and Museum, Johnny Cash Museum, Musicians Hall of Fame and Museum, National Museum of African American Music, and Patsy Cline Museum.",
#     "reasoning": "Chunks filtered for music/musician-related categories in Nashville."
#   },
#   {
#     "question": "Are there botanical gardens in the available locations?",
#     "chunk_ids": [134, 143, 1443, 2811, 949],
#     "answer_example": "Botanical gardens include Lake Eola Park (Orlando), WRAL Azalea Garden (Raleigh), Lyndale Park Rose Garden (Minneapolis), Longue Vue House & Gardens (New Orleans), and Conservancy of Southwest Florida (Naples).",
#     "reasoning": "Chunks chosen by presence of 'garden' or 'botanical' in the name or categories."
#   },
#   {
#     "question": "Are there theme parks suitable for family outings in San Diego?",
#     "chunk_ids": [1062, 1064, 1069, 1077],
#     "answer_example": "Yes, SeaWorld San Diego, Mission Bay Park, Flyover, and Ski Beach Park are suitable for family-friendly theme park outings.",
#     "reasoning": "Chunks are theme parks or entertainment complexes in San Diego for families."
#   },
#   {
#     "question": "What attractions in Charleston, SC are related to US Civil War history?",
#     "chunk_ids": [1741, 1744, 1765, 1750, 1746, 1762],
#     "answer_example": "Civil War-related sites in Charleston include The Old Slave Mart Museum, McLeod Plantation Historic Site, Fort Sumter and Fort Moultrie National Historical Park, Friends of the Hunley, Nathaniel Russell House, and Powder Magazine.",
#     "reasoning": "Chunks chosen by historical relevance and visitor focus."
#   },
#   {
#     "question": "Which cities have more than three parks listed in your database?",
#     "chunk_ids": [0, 12, 19, 20, 43, 127, 357, 359, 361, 362, 363, 364, 365, 366, 367],
#     "answer_example": "Savannah, Houston, and Minneapolis each have more than three parks listed in the database.",
#     "reasoning": "Chunks show multiple parks per city (Savannah, Houston, Minneapolis, etc.)."
#   },
#   {
#     "question": "Are there any amusement or water parks in Charlotte, NC?",
#     "chunk_ids": [1138, 1148],
#     "answer_example": "Yes, Christmas Town USA (seasonal amusement) and MagiQuest are options in Charlotte, NC.",
#     "reasoning": "Chunks 1138, 1148 indicate amusement/entertainment parks."
#   },
#   {
#     "question": "I want a list of all aquariums in the listed US cities.",
#     "chunk_ids": [801, 172, 232, 139, 1053, 973, 1409, 128, 131, 1491, 803, 409, 1391, 1062, 2561],
#     "answer_example": "Aquariums include Mote Marine Lab & Aquarium (Sarasota), New England Aquarium (Boston), National Aquarium (Baltimore), SEA LIFE Orlando Aquarium, Shedd Aquarium (Chicago), Tennessee Aquarium (Chattanooga), OdySea Aquarium (Scottsdale), SeaWorld Orlando, Aquatica Orlando, Sea Life Park Hawaii, Sarasota Jungle Gardens (zoo/aquarium), Philadelphia Zoo, Shreveport Aquarium, SeaWorld San Diego, and Oklahoma City Zoo.",
#     "reasoning": "Chunks represent all aquariums found by city/state filter."
#   },
#   {
#     "question": "Which museums are noted for their African American history?",
#     "chunk_ids": [25, 29, 194, 711, 158, 203, 1582, 1603, 292, 1588, 1879, 1558, 869, 343, 867, 293, 667],
#     "answer_example": "Examples: Ralph Mark Gilbert Civil Rights Museum (Savannah), Beach Institute African American Cultural Center (Savannah), Museum of African American History (Boston), National Underground Railroad Freedom Center (Cincinnati), National Museum of African American Music (Nashville), Levine Museum of the New South (Charlotte), Black American West Museum & Heritage Center (Denver), and others.",
#     "reasoning": "Filtered museums by African American theme or explicit presence in name."
#   },
#   {
#     "question": "What are the oldest historic houses or homes available as attractions?",
#     "chunk_ids": [10, 14, 284, 300, 346, 352, 370, 380, 520, 713, 720, 117, 731, 273, 304, 431],
#     "answer_example": "Examples: Andrew Low House (Savannah), Mercer Williams House Museum (Savannah), Beehive House (Salt Lake City), Chandler House Museum (Chicago), The Witches' Tree (Louisville), Conrad-Caldwell House Museum (Louisville), Thornhill Estate (St. Louis), General Crook House Museum (Omaha), Glessner House (Chicago), Molly Brown House Museum (Denver), Mary Todd Lincoln House (Lexington), Harriet Beecher Stowe House (Cincinnati), etc.",
#     "reasoning": "Historic homes or houses filtered by name and historic landmark tag."
#   },
#   {
#     "question": "What’s the best place in Portland to see roses?",
#     "chunk_ids": [2841],
#     "answer_example": "The best spot is the International Rose Test Garden in Portland.",
#     "reasoning": "Chunk 2841 is a dedicated rose garden in the city."
#   },
#   {
#     "question": "Are there any chocolate factories open for tours in the available attractions?",
#     "chunk_ids": [],
#     "answer_example": "None of the available attractions are chocolate factories or offer chocolate-related tours.",
#     "reasoning": "No chunk mentions chocolate factory or related keywords."
#   },
#   {
#     "question": "Can I find information on skydiving centers in the attractions?",
#     "chunk_ids": [],
#     "answer_example": "No skydiving centers are present in the listed attractions.",
#     "reasoning": "No chunk includes skydiving as a main category or in the name."
#   },
#   {
#     "question": "Are any of the attractions focused on fossil or dinosaur exhibits?",
#     "chunk_ids": [],
#     "answer_example": "Specific fossil or dinosaur museums are not listed among the available attractions.",
#     "reasoning": "No chunk is primarily a fossil or dinosaur-themed museum (though some natural history museums may contain such exhibits)."
#   },
#   {
#     "question": "Are any of the listed attractions specifically dog parks?",
#     "chunk_ids": [],
#     "answer_example": "There are no attractions whose main purpose is specifically a dog park.",
#     "reasoning": "None of the chunks have 'Dog park' as the sole/primary category."
#   },
#   {
#     "question": "Can I book a hot air balloon tour at any of the available locations?",
#     "chunk_ids": [],
#     "answer_example": "No, hot air balloon tours are not listed among the available attractions.",
#     "reasoning": "No chunk refers to hot air balloons or similar experiences."
#   }
# ]
# ```

# %% [markdown]
# ## Clean up output and make it json parseable

# %%
import json

json_output = response.choices[0].message.content
json_output = json_output.replace("```json", "")
json_output = json_output.replace("```", "")
# json_output = json_output.replace("// Questions that CANNOT be answered from the available chunks", "")
json_output = json.loads(json_output)

# %% [markdown]
# ## Upload dataset to LangSmith

# %%
from langsmith import Client
import os

client = Client(api_key=os.environ["LANGSMITH_API_KEY"])

dataset_name = "travel-rag-evaluation-dataset"
dataset = client.create_dataset(
    dataset_name=dataset_name,
    description="Dataset for evaluating RAG pipeline"
)

# %%
for item in json_output:
    client.create_example(
        dataset_id=dataset.id,
        inputs={"question": item["question"]},
        outputs={
            "ground_truth": item["answer_example"],
            "context_ids": item["chunk_ids"],
            "contexts": [row_list[idx] for idx in item["chunk_ids"]]
        }
    )
