# %% [markdown]
# # Text2Sql

# %%
from openai import OpenAI
import os
import psycopg2
import instructor
from pydantic import BaseModel
import openai
import sqlvalidator
from langchain_community.utilities import SQLDatabase
from langchain.chains import create_sql_query_chain

# %%
postgres_username = os.getenv("POSTGRES_USERNAME")
postgres_pwd = os.getenv("POSTGRES_PASSWORD")

# %%
print(postgres_username)
# Out:
# postgres

# %%
client = instructor.from_openai(OpenAI())
db_chain = SQLDatabase.from_uri(f"postgresql+psycopg2://{postgres_username}:{postgres_pwd}@host.docker.internal:5433/postgresdb")
# Out:
# /workspaces/agentic-travel-assistant/.venv/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'vector' of column 'embedding'
#   self._metadata.reflect(

# %%
class SQLQuery(BaseModel):
    query: str


class RAGGenerationResponse(BaseModel):
    answer: str

# %%
# Text2Sql

# query = "What is the top 5 attraction location in the US based on ratings?"
# query = "I want a list of all aquariums in the listed US cities."
query = "Are there any amusement or water parks in Charlotte, NC?"
# query = "Which cities have more than three parks listed in your database?"
# query = "What attractions in Charleston, SC are related to US Civil War history?"

prompt = f"""
You are given a database schema:
    Schema: public
    Table: us_attractions
    Columns:
    - name VARCHAR(250)
    - main_category VARCHAR(250)
    - rating REAL
    - reviews REAL
    - categories VARCHAR(250)
    - address VARCHAR(250)
    - city VARCHAR(250)
    - country VARCHAR(250)
    - state VARCHAR(250)
    - zipcode INTEGER
    - broader_category VARCHAR(250)
    - weighted_score REAL
    - weighted_average REAL
    - all_cities VARCHAR(250)

The values under the country column are all "USA".    

Translate the following query into SQL:

"{query}"

Instructions:
- Write SQL query using the "public" schema for all tables (e.g., public.us_attraction).
- Response should only be a safe SQL query
- When making string comparisons, make sure to perform lower case

"""

# print(prompt)

# %%
def is_structured_query(question: str) -> bool:
    structured_keywords = [
        "select", "count", "list", "find", "show", "where", "when", "which",
        "how many", "exactly", "order by", "group by", "price", "location", "category",
        "top", "maximum", "minimum"
    ]
    question_lower = question.lower()
    return any(keyword in question_lower for keyword in structured_keywords)


def is_valid_sql(query):
    parsed = sqlvalidator.parse(query)
    return parsed.is_valid()

# %%
is_structured_query(query)
# Out:
# False

# %%
# Instructor Version

response, raw_response = client.chat.completions.create_with_completion(
    model="gpt-4.1-mini",
    response_model=SQLQuery,
    messages=[{"role":"user", "content": prompt}],
    temperature=0
)

# %%
response
# Out:
# SQLQuery(query="SELECT name, city FROM public.us_attractions WHERE main_category = 'Aquarium';")

# %%
response.query
# Out:
# "SELECT * FROM public.us_attractions WHERE lower(city) = 'charleston' AND lower(state) = 'sc' AND (lower(main_category) LIKE '%civil war%' OR lower(categories) LIKE '%civil war%' OR lower(broader_category) LIKE '%civil war%')"

# %%
parsed = sqlvalidator.parse(response.query)
parsed.is_valid()
# Out:
# True

# %%
# OpenAI
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[{"role": "user", "content": prompt}],
    temperature=0.,
)

# %%
str(response.choices[0].message.content)
# Out:
# '```sql\nSELECT name, city, state, rating\nFROM public.us_attractions\nORDER BY rating DESC\nLIMIT 5;\n```'

# %%
parsed = sqlvalidator.parse(response.choices[0].message.content)
parsed.is_valid()
# Out:
# False

# %%
conn = psycopg2.connect(
    dbname="postgresdb",
    user=postgres_username,
    password=postgres_pwd,
    host="host.docker.internal",  # e.g., "localhost"
    port="5433"        # default PostgreSQL port
)
cursor = conn.cursor()

# %%
generated_sql = response.query

cursor.execute(generated_sql)
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('American Legacy Tours', 'Cincinnati', 'OH', 5.0, 3249.0)
# ('Far Shot Albany', 'Albany', 'NY', 5.0, 2830.0)
# ('Axehole Vegas | Axe Throwing Bar', 'Las-vegas', 'NV', 5.0, 2653.0)
# ('Immersive Gamebox - 9+CO Denver', 'Denver', 'CO', 5.0, 2052.0)
# ('Buffalo Double Decker Tours', 'Buffalo', 'NY', 5.0, 1626.0)

# %%
query_embedding = openai.embeddings.create(
    input=[query],
    model="text-embedding-3-small"
)

# %%
len(query_embedding.data[0].embedding)
# Out:
# 1536

# %%
# Example to perform vector similarity queries

# query_embedding = [0.1, 0.2, ..., 0.3]
cursor.execute(
  "SELECT * FROM public.us_attractions ORDER BY embedding <-> %s::vector LIMIT 5",
  (query_embedding.data[0].embedding,)
)
results = cursor.fetchall()

# %%
results
# Out:
# [(1761,
#   'Fort Sumter and Fort Moultrie National Historical Park',
#   'Tourist attraction',
#   4.7,
#   136.0,
#   'Tourist attraction, Museum',
#   'Fort Sumter and Fort Moultrie National Historical Park, 340 Concord St, Charleston, SC 29401',
#   'Charleston',
#   'USA',
#   'SC',
#   None,
#   'Entertainment',
#   639.2,
#   4.51,
#   'Augusta, Charleston, Columbia, Greenville, Myrtle-beach',
#   '[0.022784065,-0.026257118,0.012772885,0.03307769,0.0031330704,0.003941183,-0.011883699,-0.022846831,-0.01949931,0.0053246506,0.0024596434,0.012354445,-0.01917502,-0.01783601,0.047325578,-0.019509772,-0.008410647,0.01344239,0.047158204,0.05983694,0.03012769,-0.016225016,0.00016361663,-0.020576794,-0.010963132,0.011109586,-0.09908663,0.0017221427,-0.039228763,0.066908576,0.025734069,-0.029625561,-0.02034665,0.024269527,0.045484442,0.087286614,-0.031529464,0.020074666,-0.027135843,0.0012173993,0.045275223,-0.0007937286,-0.002324958,0.01230214,0.029311731,-0.043643307,-0.022679456,0.01919594,-0.039103232,0.022344703,0.00927891,0.00338675,0.00017652943,-0.0067996522,-0.007144865,-0.00896508,-0.010670223,-0.03512805,0.010910827,0.00070284866,0.039291527,-0.019028565,0.036529824,-0.005481566,-0.043099333,0.038642947,-0.025671301,0.022407468,0.0007603842,-0.016967747,0.03973089,0.003096457,0.03502344,-0.015994875,0.011956926,0.029960314,-0.033851806,0.015022001,0.0034625921,-0.046907138,-0.0007983053,-0.008734938,0.0055757146,0.022344703,-0.07611426,0.002178504,0.028537618,0.018536897,-0.0014606176,0.07163695,-0.014739553,-0.022261014,0.01417466,0.0078196,0.020053744,-0.013149481,-0.04565182,-0.016308704,0.008886622,0.028642228,-0.011548948,-0.06678305,-0.0026479415,-0.05368587,0.043768838,0.023432648,0.009263218,0.015994875,-0.044773094,0.024374139,-0.06180361,0.017658174,-0.044396497,0.013996823,0.009859496,0.026738325,0.05397878,-0.051761046,-0.0057640127,0.038747557,-0.030483363,-0.020712787,0.015042922,-0.031571306,-0.008740168,0.018170763,-0.033809964,-0.012898417,0.028223787,-0.04318302,0.035295427,-0.012343984,-0.008598945,-0.015074306,0.0059993854,0.008614636,0.011151429,-0.015921647,-0.030420598,-0.0033789042,0.010696376,0.035086203,0.0066375067,0.0070454855,0.017553564,-0.028767759,-0.015053384,0.01000595,0.04056777,0.006956567,-0.026089743,0.006098765,0.02502272,0.0011474413,-0.013547,-0.07506816,-0.0068205744,-0.0044459263,-0.030190455,0.050714944,-0.006658429,-0.021204453,-0.02669648,0.014530334,-0.0014645405,0.06925184,-0.038203586,-0.013798064,-0.044396497,-0.0023301884,0.03544188,-0.034228403,-0.046656076,-0.013630687,0.018578742,0.011402493,-0.0038836475,0.009985028,-0.031236555,0.03523266,-0.027135843,-0.007029794,0.0091586085,0.035086203,0.013944518,0.013808524,0.0008185735,0.012626431,0.004859136,0.02138229,-0.0049794377,-0.05962772,-0.019530693,-0.0204408,-0.01887165,-0.040274862,-0.011172351,-0.029583717,-0.011172351,0.02834932,-0.007704529,0.034061026,0.040484082,-0.021654276,-0.064941905,0.008666941,0.034207482,0.065820634,0.06410503,0.021005694,0.027052155,0.001403082,0.0122079905,-0.01261597,-0.0012880111,0.010440081,-0.07941994,-0.008666941,0.0012867034,-0.017668635,-0.03535819,0.012249835,0.026236197,0.044856783,0.00573786,0.030441519,-0.011548948,-0.024729813,0.002837547,0.040002875,-0.02334896,0.012542743,-0.019530693,0.0022504234,-0.034458544,-0.031257477,0.024750734,-0.015147533,-0.006224297,0.039019544,0.017292038,-0.0027564743,0.024939032,-0.0023001132,0.018338138,-0.011412955,0.04573551,-0.0011232502,0.013923596,0.04619579,0.02439506,0.046656076,0.006517205,0.030713506,0.0067944215,-0.013881751,0.00025351587,-0.028809603,0.019656226,-0.02190534,-0.013097176,-0.0042314758,0.010858522,-0.043434087,0.021288142,0.011433877,-0.011067742,0.047660332,-0.03617415,-0.026738325,0.02305605,-0.044689406,-0.019614382,-0.025420237,-0.00896508,-0.023788322,-0.021392751,0.0347933,-0.03284755,0.009320754,0.015388136,-0.05150998,-0.030295067,-0.02387201,-0.017595408,0.025734069,0.010141943,-0.023495413,-0.010617918,0.048120614,0.0020202813,0.009435825,-0.028537618,-0.047074515,-0.014676788,0.010900365,0.0033161382,-0.032701097,0.03824543,0.012333523,0.013023949,0.012249835,-0.068163894,0.020189736,0.004757141,0.04904118,-0.031864215,0.01011579,0.014394341,0.01720835,-0.0429738,-0.07305965,0.0112978835,-0.02970925,-0.016925903,-0.0013010873,0.0111200465,0.034542233,-0.059920628,0.009911801,0.044773094,-0.033600744, ...
#  (1739,
#   'The Charleston Museum',
#   'Museum',
#   4.6,
#   1891.0,
#   'Museum, Historical landmark, History museum, Natural history museum, Tourist attraction',
#   'The Charleston Museum, 360 Meeting St, Charleston, SC 29403',
#   'Charleston',
#   'USA',
#   'SC',
#   None,
#   'Cultural',
#   8698.6,
#   4.64,
#   'Augusta, Charleston, Columbia, Greenville, Myrtle-beach',
#   '[0.029842041,-0.029819604,0.016906751,0.0493179,-0.02551158,0.038682465,-0.02465895,-0.011488064,-0.03448663,-0.04339437,0.0029898137,-0.024524324,0.014483487,-0.0031889474,0.018466165,0.013126011,-0.031524863,0.018286664,0.06681925,0.015470742,0.018589573,-0.029034287,-0.0028888443,-0.009990353,0.021786934,0.0051241927,-0.068075754,0.004148156,-0.010124979,0.06417161,0.0045688613,-0.033678874,-0.024546763,0.01805107,0.0059740175,0.108598106,-0.013081135,-0.011835847,-0.003334792,0.017725725,0.039624847,-0.0069949296,-0.0065966616,-0.005233576,0.040948667,0.010523247,-0.020025581,0.024165323,-0.044157248,0.017333066,-0.024703825,-0.009087238,-0.01796132,-0.006736897,-0.015807306,-0.044942565,0.020866992,-0.028697724,-0.008559954,0.042653926,0.049766652,-0.03731377,0.04575032,-0.011123452,-0.048869148,-0.0072585717,-0.03316281,0.06340873,-0.04330462,-0.011460017,0.044807937,0.043820683,-0.009373318,0.011600252,-0.0053064986,-0.010444715,-0.012935291,0.00069346285,0.004790433,-0.008144858,-0.032422367,0.0050316374,-0.028877225,0.014180579,-0.04545863,-0.006349848,0.057574946,0.032175556,-0.008077545,0.0718004,-0.02703734,-0.014483487,0.04368606,0.014539581,0.045211814,-0.026992463,-0.024928201,-0.018712979,0.012553851,0.0045604473,-0.02418776,-0.0629151,-0.011190766,-0.05340155,-0.02465895,0.037179146,0.004139742,-0.0054299054,-0.03960241,0.021977654,-0.10312333,-0.016121434,-0.045346443,0.039894097,-0.031951178,0.021932779,0.033678874,-0.022830283,0.0063442388,0.027508529,-0.03089661,-0.009087238,0.010354964,-0.064844735,-0.0068042097,-0.0052588186,-0.0050709033,-0.006815429,0.031031236,-0.021282088,0.013339168,-0.042653926,0.011757316,-0.07310178,0.014808833,-0.02285272,0.017994976,-0.011936816,-0.045862507,-0.009945477,0.020519208,0.008206561,0.025646206,0.04245199,0.030739548,-0.002664468,-0.008627267,0.039647285,0.05214504,0.032242868,-0.03383594,0.020530427,0.039759472,0.015627805,0.008352406,-0.038121525,0.007999013,0.00044244193,-0.044246998,0.030919047,0.03522707,-0.00069135934,-0.024210198,-0.004641784,-0.047029264,0.069511764,-0.0752558,0.05452343,-0.03646114,-0.003051517,-0.0059964554,-0.02362682,-0.049587153,-0.02087821,-0.013642076,0.002264798,0.006456427,0.00074324635,0.0058281734,0.030313231,-0.0072361343,-0.012172412,0.021136243,0.0018230571,-0.011959255,0.021248432,-0.030492732,0.02304344,-0.006983711,0.031951178,-0.020339707,-0.011392704,0.019700235,-0.015223929,-0.013821578,-0.036797706,0.022886379,-0.028338721,0.0023994236,0.021708403,-0.051516786,0.023559507,0.061568845,-0.03778496,-0.049946155,0.020474333,0.0072585717,0.060985465,-0.0055701407,0.005556117,0.014797614,0.0061423,0.037448395,0.029483039,-0.009451849,0.002165231,-0.057350572,-0.017422816,-0.026723212,-0.015639026,-0.067537256,0.03993897,0.031322926,0.035496324,0.012553851,0.013686951,-0.041733984,-0.025017953,-0.0016014855,0.03042542,-0.0105064185,0.023783883,-0.008116811,-0.010826155,-0.07081315,-0.045436192,0.008189733,-0.008520688,-0.011948035,0.022920035,0.011723659,0.0036124578,0.04072429,0.03908634,0.05138216,-0.010641044,0.028338721,-0.03004398,-0.026341772,0.040006287,0.024120448,0.021472808,-0.019330014,0.020597741,0.024703825,0.008862862,-0.067043625,-0.0122846,0.010618607,-0.013384043,0.015739994,-0.023110755,0.028675286,-0.017613536,0.010147416,-0.004223883,-0.03740352,0.029258663,-0.0406121,-0.02333513,0.017030157,-0.023604382,-0.033993002,-0.0028692114,-0.008672142,0.0078924345,-0.02049677,0.0060525495,-0.019195389,0.0023755836,-0.018017413,-0.022549814,0.0015846572,0.0068546943,-0.03468857,0.039422907,0.0146629885,-0.030963924,-0.004392165,0.061434217,0.00064332876,-0.041980796,-0.03787471,-0.026409086,-0.053356674,0.027104652,0.027127089,-0.04631126,0.061299592,0.0075390423,-0.028271409,-0.021562558,-0.024838451,-0.014427393,0.0028187267,0.105546586,-0.029505478,-0.03628164,0.018185696,-0.014932239,-0.031951178,-0.043057803,0.017119909,-0.026700774,-0.033050623,4.614613e-05,-0.0009669214,0.025556454,-0.05528631,0.017703287,- ...
#  (1777,
#   'Charleston, South Carolina',
#   'Tourist attraction',
#   4.7,
#   76.0,
#   'Tourist attraction',
#   'Charleston, South Carolina, Charleston, SC 29401',
#   'Charleston',
#   'USA',
#   'SC',
#   None,
#   'Entertainment',
#   357.2,
#   4.51,
#   'Augusta, Charleston, Columbia, Greenville, Myrtle-beach',
#   '[0.04405034,-0.04804295,-0.00056900183,0.07033137,-0.042383097,-0.006312493,-0.03461725,-0.0036553226,-0.028452834,-0.022595543,-0.0083417045,-0.026039718,-0.008610438,0.007151599,0.015400069,-0.018800369,-0.034200437,0.013579263,0.038302734,0.04389678,0.017363468,-0.027443713,-0.02032502,-0.036108993,0.04514721,-0.0017124899,-0.0617319,0.02288073,-0.021388985,0.05229881,0.009361794,-0.03597737,0.027597275,-0.0011085253,0.035823807,0.079896085,-0.011286803,-0.0127675785,0.0028326693,-0.006564773,0.033893313,-0.0055830735,-0.012614016,0.039355733,0.012965015,0.011528115,-0.029966516,0.03027364,-0.049797945,0.030712388,-0.024855098,0.0031343088,-0.00038527595,-0.005912135,-0.021213485,-0.0077713314,0.0015356194,-0.005481613,0.008879171,0.029198706,0.034266252,-0.0019825944,0.025776468,0.011352615,-0.042141784,-0.008846264,-0.04049648,0.043348342,-0.03459531,-0.0054432224,0.023429165,-0.00026667677,0.019546242,-0.006444117,0.007195474,0.031151136,-0.010359947,-0.034397874,0.041264288,-0.023187853,-0.017528,0.006904803,-0.029264519,-0.009932167,-0.06269715,0.013173421,0.066470385,-0.004247633,0.030646576,0.04786745,-0.016639533,-0.0074532386,0.027355963,-0.00020292113,0.034354,-0.029615518,-0.0316557,0.014906477,0.030778201,0.0067128506,0.00423118,-0.052605934,-0.017835123,-0.047911327,0.019502366,0.047999077,-0.039794482,0.040342916,-0.01032704,-0.009751183,-0.06581226,0.01207655,-0.05295693,0.0029560674,-0.01275661,-0.008561078,0.039092485,-0.06726013,0.0014999711,0.035757996,-0.03332294,-0.016255628,0.013656044,-0.06357464,-0.032642882,0.010107666,-0.010518993,-0.028101835,0.02118058,-0.04339222,0.0024035187,-0.0047110613,-0.0033838472,-0.035297308,-0.0017097477,0.02116961,-0.0030328485,-0.03731555,-0.036043182,0.023078166,-0.0039459937,0.04082554,0.013447639,0.010793211,0.029132895,0.011319709,-0.026719779,0.039004732,0.033059694,0.010146057,-0.054053806,0.014467728,0.016431129,0.0056434013,-0.0093837315,-0.065285765,0.0064221798,-0.01803256,-0.022573605,0.01828484,0.017900934,-0.03216026,-0.054185428,0.01649694,-0.013754763,0.039333794,-0.023231728,0.047911327,-0.054624178,0.0029121926,0.040913288,-0.052605934,-0.047033828,-0.022321325,0.010661586,0.0075080823,0.028869646,0.009614075,-0.017725436,0.027202401,-0.008950467,-0.019107493,0.02959358,0.011912019,0.0018797627,0.014873571,-0.0039651887,0.032577068,-0.0054788706,0.022441981,-0.0013772587,-0.01420448,0.01615691,-0.026741715,-0.03053689,-0.027026903,-0.015542663,-0.009762152,-0.030756263,0.022266481,-0.013656044,0.0009830707,0.03893892,-0.035253435,-0.051684562,0.033366818,-0.0028326693,0.04218566,0.06309202,-0.019348804,0.051158063,0.020873455,0.009493419,0.0071077244,-0.0053499886,0.004922209,-0.027772775,0.009125967,-0.001451983,-0.024898972,-0.06467152,0.060415655,0.04729708,0.019776585,0.0003018109,0.018065466,-0.01982046,-0.010063792,0.014610322,0.06028403,-0.028759958,0.043172844,0.013151484,-0.025622906,-0.06651426,-0.03716199,0.0034633703,-0.009630527,-0.01784609,0.0050839973,0.016902782,0.019239118,0.030844012,0.027904399,0.060503405,-0.019513335,0.036613554,0.041988224,-0.027685024,0.05409768,0.047999077,0.029900704,-1.0020731e-05,0.02305623,0.029747142,-0.015970442,-0.014325135,-0.011769426,0.031326637,-0.0024213428,0.01667244,-0.01658469,0.025798406,-0.049008198,0.014379979,-0.020445677,-0.017484125,0.022595543,-0.017988686,-0.041132662,0.016288534,-0.048086826,-0.0070364275,-0.025842281,-0.037534926,-0.03213832,0.0031178559,-0.011571989,-0.033695877,0.013623138,-0.006948678,-0.030405264,-0.023604665,-0.0051470674,-0.013590232,0.019831428,0.011385521,-0.02270523,-0.015630413,0.07107724,0.0062686177,-0.023012353,-0.06554901,-0.0077439095,-0.030514952,0.018273871,0.025030596,-0.037381366,0.05901166,-0.0072064428,0.034178503,0.013206327,-0.041724972,0.0007506711,0.0072064428,0.06181965,-0.048876572,0.024635723,0.011045491,-0.014588385,-0.03784205,-0.04233922,0.047077704,-0.019952083,3.02068e-05,-0.020226302,-0.006378305,0.048130702,-0.032577068,0.01224108,0 ...
#  (1767,
#   'South Carolina Historical Society',
#   'Museum',
#   4.4,
#   70.0,
#   'Museum, Historical landmark, Tourist attraction',
#   'South Carolina Historical Society, 100 Meeting St, Charleston, SC 29401',
#   'Charleston',
#   'USA',
#   'SC',
#   None,
#   'Cultural',
#   308.0,
#   4.64,
#   'Augusta, Charleston, Columbia, Greenville, Myrtle-beach',
#   '[0.01754793,-0.039988402,0.016275868,0.05953684,-0.044119887,0.018928714,-0.002523738,-0.024919365,-0.03870547,-0.03968398,0.015047295,-0.040771212,-0.022353496,0.0058819265,0.024593195,-0.007958541,-0.03809662,0.034182582,0.067017,0.03800964,0.021092307,-0.027115574,-0.0042728228,-0.006855,0.053100426,-0.004531041,-0.072844565,0.00835538,-0.011361578,0.056144677,-0.0009390969,-0.026637191,-0.008980539,0.01577574,0.0017558802,0.10828834,-0.007088755,-0.0013658355,-0.0044984235,-0.0018374226,0.019341862,-0.02583264,-0.013764361,0.0112311095,0.03135578,-0.000725048,-0.00638749,0.0016009496,-0.064625084,0.010589642,-0.032638714,-0.0042918497,-0.020863988,-0.029942378,-0.014025297,-0.03216033,0.019102672,-0.01521038,-0.0030197876,0.058667056,0.05892799,-0.022157794,0.047533795,-0.015558294,-0.03459573,-0.010573334,-0.03318233,0.044054653,-0.05236111,-0.0025482008,0.02789838,0.005400826,-0.0149385715,0.0029436816,-0.029290037,-0.01011126,-0.010714674,-0.00045018212,0.020429095,0.009991664,-0.013742616,-0.001512612,-0.0139165735,0.010252601,-0.072409675,-0.018276375,0.048794985,0.041380063,-0.007779147,0.067886785,-0.0020073026,0.019276628,0.03635705,0.003574276,0.049403835,-0.04975175,-0.053796254,-0.015416954,0.028094083,-0.0016743378,-0.012318342,-0.057579823,-0.0032018991,-0.063363895,-0.0222339,0.033051863,-0.026289277,-0.0065342663,-0.03135578,0.03411735,-0.10907114,-0.015982315,-0.077845834,0.046272606,-0.0035606858,0.017243505,0.010785344,-0.06932193,0.0065451385,0.07319248,-0.013003298,-0.005653608,-0.013372958,-0.07140942,-0.00072912517,0.003737361,-0.012470555,-0.027746169,0.025571704,-0.027833147,0.01380785,-0.047229372,0.006191788,-0.04381546,0.005555757,0.0031067664,-0.002824086,-0.028681189,-0.047794733,-0.004278259,-0.004126047,0.0038787012,0.015949698,0.040010147,0.053622298,0.00484362,-0.012416193,0.030464249,0.020983584,0.014731998,0.002659642,0.028202806,0.010393941,0.010948429,6.842981e-06,-0.01722176,-0.0033595478,0.0068223826,-0.020755265,0.029572718,0.01474287,-0.015580039,-0.0043815463,0.033660714,-0.049055923,0.06575581,-0.012024789,0.032269053,-0.040010147,0.00028319005,0.017754503,-0.023136303,-0.019254884,-0.027985359,-0.019983329,0.001682492,0.013155511,0.011029972,-0.012688001,0.01754793,0.005283949,-0.021853369,0.012644512,-0.00627333,-0.0061102454,-0.0021323343,-0.01029609,0.029572718,-0.025289023,0.028420253,-0.0016240532,-0.0113180885,0.029920632,-0.005463342,-0.0093991235,-0.01567789,0.029724931,-0.007099627,-0.04390244,0.023136303,-0.04338057,0.004946907,0.0051045557,-0.023832131,-0.04207589,-0.0033568298,-0.0059471605,0.04418512,0.021461966,0.0013848621,0.015667018,0.005555757,0.013546915,0.039597,0.0022111586,0.0036829994,-0.06753887,-0.019113544,-0.0060830647,-0.019559309,-0.074105754,0.033443265,0.02742,0.03700939,0.016275868,0.014634146,-0.027637444,-0.0010410249,-0.0063113836,0.00012885402,-0.00599065,0.03918385,0.0019148879,-0.0012047893,-0.057840757,-0.02335375,-0.012959809,-0.01366651,-0.021505455,0.042858697,-0.00010812865,-0.01011126,0.046316095,0.022657922,0.054318126,-0.017384844,0.026463235,-0.021124924,-0.03163846,0.051882725,0.014003552,0.04064074,0.018689523,0.058188673,0.021440221,-0.010953865,-0.047620773,-0.039901424,0.018308992,-0.027180808,0.010181931,-0.028789911,0.037096366,-0.008132498,0.026224043,-0.017113036,-0.024332259,0.02457145,-0.038118366,-0.024506217,-0.0006700069,-0.01183996,-0.0024870439,0.0039113183,0.010823398,-0.02125539,-0.021972965,0.031094844,-0.029050848,-0.010785344,-0.017700141,-0.038118366,-0.020972712,0.02770268,-0.02709383,0.044315588,0.02138586,-0.038292322,0.009127315,0.059319396,0.009393687,-0.062320154,-0.030768674,-0.0093991235,-0.049055923,0.009350197,0.029833654,-0.008426051,0.03387816,0.0046968437,-0.017428333,-0.02307107,-0.03224731,-0.018798247,0.017091291,0.07101801,-0.03216033,-0.0072137862,0.0083336355,-0.03509586,-0.012764107,-0.017950205,0.024440981,-0.021896858,-0.010285217,-0.015123401,-0.0066158087,0.03172544,-0.029833654,-0.014 ...
#  (347,
#   'Museum & Library of Confederate History',
#   'History museum',
#   4.6,
#   243.0,
#   'History museum, Tourist attraction',
#   'Museum & Library of Confederate History, 15 Boyce Ave, Greenville, SC 29601',
#   'Greenville',
#   'USA',
#   'SC',
#   None,
#   'Cultural',
#   1117.8,
#   4.64,
#   'Augusta, Charleston, Columbia, Greenville, Myrtle-beach',
#   '[0.022521766,-0.013041217,0.02407273,0.01901571,-0.02654117,-0.013685632,-0.021167401,-0.032439206,-0.04731537,-0.029577566,-0.0061328667,-0.028288737,-0.027655244,-0.0020984453,0.010654696,-0.015302131,0.031762026,0.037157636,0.041198887,0.06024736,0.04569887,-0.0104854,0.03235183,0.016590962,-0.0073507023,0.0101413485,-0.053912435,-0.004221466,-0.0037681907,0.006733593,0.00013149416,-0.03645861,-0.035431914,0.009950208,-0.022434387,0.0810871,0.002987247,-0.004592824,0.022183174,0.008208103,0.058106594,-0.025492629,-0.020359153,-0.013314274,0.0034650972,-0.05094157,-0.016809408,0.031893093,-0.07335411,0.016514506,-0.047402747,-0.055397864,-0.06483473,-0.0040576314,-0.03663337,-0.0020137976,-0.010785763,-0.06404832,-0.00069220026,0.007257863,0.07894633,-0.011632241,-0.006362235,-0.040303256,-0.006913811,0.010725691,-0.0024124612,0.044825085,-0.008257253,-0.01276816,0.019387068,0.026934372,-0.0031565423,0.004879534,0.019594591,0.0019359762,-0.018469596,0.024859136,-0.0047539277,-0.030058147,-0.047490127,-0.029905235,0.005474799,0.03940763,-0.04130811,-0.016798485,0.03121591,0.053169716,0.0316528,0.06321823,0.016132224,-0.008077035,0.023897976,-0.018076394,0.02034823,-0.033793572,-0.016088536,-0.028616404,0.029992614,0.031674646,-0.018698964,-0.06618909,0.036152788,-0.06387357,0.016590962,0.016569117,-0.03444891,-0.0028561794,-0.043514412,0.03827171,-0.08973755,-0.020785121,-0.0025162231,0.042050824,-0.005985416,0.007956889,0.0048631504,-0.059635714,-0.029621257,0.05150953,-0.02758971,-0.025143117,0.0005485038,-0.07444634,-0.010742074,0.009283948,-0.003230268,-0.035431914,-0.00948601,-0.029664945,0.028616404,-0.06024736,0.036917347,-0.048058085,-0.011981755,0.02206303,0.006460536,-0.017497512,-0.019321535,-0.0022841243,0.021036334,0.0071595623,-0.012451413,0.006799127,0.032046005,-0.026038744,-0.06203862,0.022893123,0.035912495,0.017715957,0.0045245592,0.019758426,0.026344568,-0.046965856,-0.06461628,-0.039101806,0.00872145,-0.011402872,-0.020271774,0.01820746,0.01181792,-0.007956889,-0.013161362,0.039757144,-0.039342094,0.07732983,0.0045190984,0.013838544,-0.019616436,0.022095798,0.04126442,-0.02306788,-0.046616342,-0.006329468,-0.017366445,0.020228084,0.046965856,0.036829967,-0.01910309,0.018076394,-0.026519325,-0.030626107,0.011391951,0.044257127,-0.025907677,0.035147935,0.017879792,-0.017737802,-0.0068919663,0.03654599,-0.02249992,-0.0006423673,0.030342126,-0.0044426424,0.0025012048,-0.02811398,0.0064878413,-0.01777057,-0.021702595,-0.012407724,-0.04384208,0.022215942,0.009813679,-0.0034295996,-0.028397959,-0.016350672,0.006515147,0.026126122,0.0007905009,-0.0012035001,0.030342126,-0.012320345,0.002101176,-0.01043625,-0.0057888147,0.030997464,-0.050548367,-0.017300911,-0.0033476825,0.0012273926,-0.057014365,0.017803336,0.0011816554,0.03654599,0.031521734,0.040893063,-0.01534582,-0.008634072,-0.0033422213,-0.0013523162,-0.0018704425,0.043448877,-0.050242543,0.044213437,-0.025274184,-0.002282759,-0.024050888,-0.027152818,0.037812974,0.047883328,-0.019955028,0.009704457,0.01796717,0.010425327,0.027393108,-0.015924701,0.041242573,-0.029948924,-0.015291208,0.06570851,-0.00571782,0.032657653,-0.03977899,0.021222014,0.01720261,0.0044044144,-0.069203645,-0.05985416,0.028834851,-0.009027274,0.04635421,0.000807567,0.035322692,-0.032417364,5.8152673e-05,-0.0028725627,0.022609144,0.03322561,-0.069028884,-0.025077583,-0.010998748,-0.032810565,-0.0052099335,-0.009283948,0.004033056,-0.024531467,-0.059985228,0.018513285,-0.0023319093,0.04451926,-0.022478078,-0.043011986,0.007874972,0.030101838,-0.01300845,0.064397834,-0.0011372836,0.0055621774,-0.006515147,0.037856665,-0.026759615,-0.06710656,-0.04465033,-0.039189182,-0.027087284,0.016077613,-0.00022612557,-0.02224871,0.017595813,0.031805713,-0.025252338,-0.039276563,-0.024880981,0.023242638,0.0072305575,0.062125996,-0.03698288,-0.017923482,0.059548337,-0.0068974276,-0.009786374,-0.033946484,-0.010387099,0.022718368,0.014450192,-0.003063703,-0.016492661,0.021789972,-0.043907613,0.003025 ...

# %%
def get_embedding(text):
    result = openai.embeddings.create(
        input=[text],
        model="text-embedding-3-small"
    )
    embedding = result.data[0].embedding 
    return embedding


def generate_sql_query(question):
    response, _ = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        response_model=SQLQuery,
        messages=[{"role":"user", "content": question}],
        temperature=0
    )
    return response


def execute_sql_query(cursor, sql_query):
    rows = list()
    if is_valid_sql(sql_query):
        cursor.execute(sql_query)
        rows = cursor.fetchall()
    return rows


def execute_sql_similarity_match(cursor, input_embedding, top_k=5):
    vector_search_sql = "SELECT * FROM us_attractions ORDER BY embedding <-> %s::vector LIMIT %s"
    cursor.execute(vector_search_sql, (input_embedding, top_k))
    rows = cursor.fetchall()
    return rows

# %%
def query_attractions(user_question, cursor):

    if is_structured_query(user_question):
        sql_query = generate_sql_query(user_question)
        sql_results = execute_sql_query(cursor, sql_query)
        return sql_results
    else: ## Perform similarity match instead
        text_embedding = get_embedding(user_question)
        sql_results = execute_sql_similarity_match(cursor, text_embedding)
        return sql_results

# %%
results = query_attractions(query, cursor)

# %%
formatted_rows = "\n".join([", ".join(map(str, row)) for row in rows])
# print(formatted_rows)

# Create a prompt for the LLM

prompt = f'''Here are the query results:\n{formatted_rows}

Generated by this SQL query: {generated_sql}\n
'''
if query:
    prompt += f"Based on these results, answer the question: {query}"

# print(prompt)

# response, raw_response = client.chat.completions.create_with_completion(
#     model="gpt-4.1-mini",
#     response_model=RAGGenerationResponse,
#     messages=[{"role":"user", "content": prompt}],
#     temperature=0
# )

response = openai.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.5,
    )

# %%
response.answer
# Out:
# 'The top 5 attraction locations in the US based on rating and number of reviews are:\n1. American Legacy Tours, Cincinnati, OH\n2. Far Shot Albany, Albany, NY\n3. Axehole Vegas | Axe Throwing Bar, Las Vegas, NV\n4. Immersive Gamebox - 9+CO Denver, Denver, CO\n5. Buffalo Double Decker Tours, Buffalo, NY'

# %%
response.choices[0].message.content
# Out:
# 'Based on the query results, the top 5 attraction locations in the US, ranked by rating (all 5.0) and then by number of reviews (highest first), are:\n\n1. American Legacy Tours, Cincinnati, OH (5.0 rating, 3249 reviews)  \n2. Far Shot Albany, Albany, NY (5.0 rating, 2830 reviews)  \n3. Axehole Vegas | Axe Throwing Bar, Las Vegas, NV (5.0 rating, 2653 reviews)  \n4. Immersive Gamebox - 9+CO Denver, Denver, CO (5.0 rating, 2052 reviews)  \n5. Buffalo Double Decker Tours, Buffalo, NY (5.0 rating, 1626 reviews)  \n\nThese are the top 5 attractions based on the highest ratings and number of reviews in the US.'

# %%
conn.close()
